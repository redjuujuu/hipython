# %%
import pymysql

# %%
# mysql 서버에 연결
con = pymysql.connect(
host='localhost',
user='root',
password='1234',
db='wntrade',
charset='utf8'
) #한글처리 (charset = 'utf8')

#커서 생성
cursor = con.cursor()

# %%
cursor.execute("show tables")
# Out:
# 7

# %%
for row in cursor.fetchall():
    print(row)
# Out:
# ('고객',)
# ('마일리지등급',)
# ('부서',)
# ('사원',)
# ('제품',)
# ('주문',)
# ('주문세부',)

# %%
#sql 쿼리 실행
sql = """
SELECT 사원번호, 이름, 부서명
FROM 사원 LEFT JOIN 부서
ON 사원.부서번호 = 부서.부서번호
"""

# %%
cursor.execute(sql)
# Out:
# 10

# %%
cursor.close()
con.close()
