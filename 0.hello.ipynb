# %%
#헬로우

# %% [markdown]
# 3*4
# 2*1
# 5*10

# %%
3*3
# Out:
# 9

# %%
3*4
2*1
5*10
# Out:
# 50

# %%
#33*4
#안녕하세요

# %%
5
# Out:
# 5

# %%
5*10
2*4
3*1
# Out:
# 3

# %%
"안녕하세요"
# Out:
# '안녕하세요'

# %%
"안녕하세요"
"반갑습니다"
# Out:
# '반갑습니다'

# %%
"안녕하세요"
"안녕"
"반갑습니다"
# Out:
# '반갑습니다'

# %%
print("안녕하세요")
"안녕"
print("반갑습니다")
# Out:
# 안녕하세요
# 반갑습니다

# %%
"안녕하세요
반갑습니다"
# Out:
#   Cell In[13], line 1
#     "안녕하세요
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"""안녕하세요
# Out:
#   Cell In[14], line 1
#     """안녕하세요
#     ^
# SyntaxError: incomplete input

# %%
"""안녕하세요
반갑습니다
사랑해요"""
# Out:
# '안녕하세요\n반갑습니다\n사랑해요'

# %%
def calculate_sum(a,b):
    result = a + b   #들여쓰기된 코드 블록
    return result    #같은 레벨의 들여쓰기
    result = calculate_sum(3,4)

if result > 0:
    print(result)
    print("양수입니다")  #if문 내부의 들여쓰기된 코드
# Out:
# 7
# 양수입니다

# %% [markdown]
# #안녕하세요

# %% [markdown]
# #안녕하세요

# %% [markdown]
# #안녕하세요

# %% [markdown]
# # 안녕하세요

# %% [markdown]
# #  안녕하세요

# %%
print(result)
# Out:
# 7

# %% [markdown]
# # Jupyter

# %% [markdown]
# ## Jupyter Notebook

# %% [markdown]
# ### Jupyter Notebook

# %% [markdown]
# #### Jupyter Notebook

# %% [markdown]
# *ㄹ아러
# *러ㅏㅇㄹ

# %% [markdown]
# * ㄹㅇㄹㄴㅇㄹ
# * 라니냐러너

# %% [markdown]
# 1. 안녕
# 2. 하이
# 3. 루루

# %%
print(result)
# Out:
# -1

# %% [markdown]
# * 아러니ㅑㅓㅇ
#     -어리나ㅓ린ㄹ

# %%
* 안녕
# Out:
#   Cell In[29], line 1
#     * 안녕
#     ^
# SyntaxError: can't use starred expression here

# %% [markdown]
# * 안녕
#   - 하이

# %% [markdown]
# * 안녕
#       -하이

# %% [markdown]
# * 안녕
#     - 하이

# %% [markdown]
# * 안녕
#       - 하이

# %% [markdown]
# <u>개구리 점프<w>
# |**번호**|**이름**|
# |------|-----|
# |1|개구리|
# |2|도마뱀|

# %% [markdown]
# ![image.png](attachment:bdba7888-f426-4fe1-a46d-091bff8788a5.png)![image.png](attachment:07d9db20-b54b-4939-8879-0ccf07e2d9f0.png)

# %% [markdown]
# ![image.png](attachment:d46f78dc-f96d-49d6-bcee-4c8523bbc3cb.png)![image.png](attachment:1db3b472-694d-4347-9835-2bfc30a7d15d.png)

# %% [markdown]
# ![image.png](attachment:a991de0a-3cea-4025-85fd-021a0fe8b6e1.png)

# %% [markdown]
# ![dohun](<https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSVmv_TDf078cTAXYiI30epfOnpDVN6SqKBqsV4Zvxcs4aQSBki1JmATObxvTtKJhkVT0NPaeLwg_MlkHswdCq9i6fKK5q4eEu25ekAMUl-&s=10>)

# %% [markdown]
# > https://youtu.be/YD_KixAviis?si=snMq3QK8KVRI-OSO
